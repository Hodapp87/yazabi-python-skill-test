# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('data/train_data.txt')
test = pd.read_csv('data/test_data.txt')

# %%
train_1 = train.replace(' ?', np.nan).dropna()
test_1 = test.replace(' ?', np.nan).dropna()

# %%
train_2 = train_1.replace(' ?', np.nan).dropna()
test_2 = test_1.replace(' ?', np.nan).dropna()

# %%
train_1
# Out:
#        37            Private  171393        HS-grad   9  \
# 0      40            Private  154076        HS-grad   9
# 1      28            Private  402771        HS-grad   9
# 2      24            Private  200819           12th   8
# 3      17            Private  121037           12th   8
# 4      37            Private  115429        HS-grad   9
# 5      19            Private  427862   Some-college  10
# 6      63            Private  230823           12th   8
# 7      28            Private  193158        HS-grad   9
# 8      31            Private  157886   Some-college  10
# 9      41            Private  173316        HS-grad   9
# 10     47            Private  151584        HS-grad   9
# 11     37       Self-emp-inc   98389        HS-grad   9
# 12     46          Local-gov  138107        Masters  14
# 13     31            Private  227146      Bachelors  13
# 14     50            Private  100109      Bachelors  13
# 15     26            Private  323044   Some-college  10
# ...
